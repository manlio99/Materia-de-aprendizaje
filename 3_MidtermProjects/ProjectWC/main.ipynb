# %% [markdown]
# # Wholesale Customers
# The goal of this project is to identify and describe the various customer segments hidden in the data. More info about this dataset in [UCI](https://archive.ics.uci.edu/ml/datasets/Wholesale+customers).

# %%
import pandas as pd
players = pd.read_csv("https://raw.githubusercontent.com/emmanueliarussi/DataScienceCapstone/master/3_MidtermProjects/ProjectWC/data/wholesale_customers data.csv")
players.head()
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-1-42b73704c8cb> in <module>()
#       1 import pandas as pd
# ----> 2 players = pd.read_csv("https://raw.githubusercontent.com/emmanueliarussi/DataScienceCapstone/master/3_MidtermProjects/ProjectWC/data/wholesale customers data.csv")
#       3 players.head()
#
# ...
